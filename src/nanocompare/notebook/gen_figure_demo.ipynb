# %%
import sys
tcgajax_prj = "/projects/li-lab/nmf_epihet/tcgajax"
sys.path.append(tcgajax_prj)

from nanocompare.plot_figures import *
# Out:
# Running on Linux

# %%
single_ds_5mc_5c_performance()
# Out:
# /projects/li-lab/nmf_epihet/tcgajax/nanocompare/load_data.py:98: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df1 = df1[df['Location'].isin(listOfSelected_cat)]
# 2020-01-16 23:57:18,377 - [plot_figures.py:50] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/singleds_nanocompare_location_f1_5c_5mc_performance_time_01-16-23-57-17-870886.png

# %%
gen_figure_3a()
# Out:
# 2020-01-16 23:57:22,191 - [plot_figures.py:168] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/scatter_facet_grid_multiple_ds_location_GW_f1_5c_5mc_performance_time_01-16-23-57-19-571718.png
# 2020-01-16 23:57:26,064 - [plot_figures.py:168] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/scatter_facet_grid_multiple_ds_location_singletons_f1_5c_5mc_performance_time_01-16-23-57-23-527638.png

# %%
gen_figure_3b()
# Out:
# 2020-01-16 23:57:29,464 - [plot_figures.py:396] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/box_plot.metric_F1_5C.region.singletons_time_01-16-23-57-26-567124.png
# 2020-01-16 23:57:32,887 - [plot_figures.py:396] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/box_plot.metric_F1_5C.region.GW_time_01-16-23-57-26-567124.png
# 2020-01-16 23:57:36,151 - [plot_figures.py:396] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/box_plot.metric_F1_5mC.region.singletons_time_01-16-23-57-26-567124.png
# 2020-01-16 23:57:39,689 - [plot_figures.py:396] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/box_plot.metric_F1_5mC.region.GW_time_01-16-23-57-26-567124.png

# %%
gen_figure_3d()
# Out:
# /projects/li-lab/nmf_epihet/results/01-16/Methylation_correlation_plotting_data.APL_oxBS_cut10.png DONE
# /projects/li-lab/nmf_epihet/results/01-16/Methylation_correlation_plotting_data.APL_WGBS_cut10.png DONE
# /projects/li-lab/nmf_epihet/results/01-16/Methylation_correlation_plotting_data.HL60_RRBS_rep_ENCFF000MDA_Bismark.png DONE
# /projects/li-lab/nmf_epihet/results/01-16/Methylation_correlation_plotting_data.HL60_RRBS_rep_ENCFF000MDF_Bismark.png DONE
# /projects/li-lab/nmf_epihet/results/01-16/Methylation_correlation_plotting_data.K562_WGBS_rep_ENCFF721JMB.png DONE
# /projects/li-lab/nmf_epihet/results/01-16/Methylation_correlation_plotting_data.K562_WGBS_rep_ENCFF867JRG.png DONE

# %%
gen_figure_3e()
# Out:
# 2020-01-16 23:58:42,948 - [plot_figures.py:515] - INFO: save to /projects/li-lab/nmf_epihet/results/01-16/nanocompare_resources_usage_01-16-23-58-41-292726.png
